# %%
salary = 100000
job_id = 101
job = 'Sales'
company = 'Google'
country = 'India'

# %%
print('Job:       ', job)
print('Job ID:    ', job_id)
print('Salary:    ', salary)
print('Company:   ', company)
print('Country:   ', country)
# Out:
# Job:        Sales
# Job ID:     101
# Salary:     100000
# Company:    Google
# Country:    India

# %%
name = 'Gajendra Arora'
salary = 100000
job = 'Assistant Professor'
Uni = 'Jaypee University'
state = 'Madhya Pradesh'
dept = 'AIML'

# %%
print('Name:      ', name)
print('Salary:    ', salary)
print('Job:       ', job)
print('University:', Uni)
print('State:     ', state)
print('Department:', dept)
# Out:
# Name:       Gajendra Arora
# Salary:     100000
# Job:        Assistant Professor
# University: Jaypee University
# State:      Madhya Pradesh
# Department: AIML
