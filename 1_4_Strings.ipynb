# %% [markdown]
# <a href="https://colab.research.google.com/github/Devvrat12/Python-High-Level-Practice-Data-Engineer/blob/main/1_4_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
skill = "Python"

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.lower()
# Out:
# 'python'

# %%
job = "Data Analyst"

# %%
job.replace("a", "o", 2)
# Out:
# 'Doto Analyst'

# %%
job.split(sep=" ", maxsplit=1)
# Out:
# ['Data', 'Analyst']

# %%
d = "I am a Data Analyst"

# %%
s = d.capitalize()

# %%
s.upper()
# Out:
# 'I AM A DATA ANALYST'

# %%
s.lower()
# Out:
# 'i am a data analyst'

# %%
s
# Out:
# 'I am a data analyst'

# %%
s.split(sep=" ")
# Out:
# ['I', 'am', 'a', 'data', 'analyst']

# %%
s.replace("data", "business")
# Out:
# 'I am a business analyst'

# %%
"Data" + " Analyst"
# Out:
# 'Data Analyst'

# %%
job
# Out:
# 'Data Analyst'

# %%
str.__add__("Business"," Analyst")
# Out:
# 'Business Analyst'

# %%
" Data Analyst" * 10
# Out:
# ' Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst'

# %%
job.__len__()
# Out:
# 12

# %%
len(job)
# Out:
# 12
