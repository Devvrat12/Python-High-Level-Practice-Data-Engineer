# %% [markdown]
# <a href="https://colab.research.google.com/github/Devvrat12/Python-High-Level-Practice-Data-Engineer/blob/main/1_3_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
job = 'Data Analyst'
salary= 100000
location = 'india'

# %%
class job_info:
  def __init__(self, job, salary, location):
    self.job = job
    self.salary = salary
    self.location = location

  def display(self):
    print(f"Job: {self.job}")
    print(f"Salary: {self.salary}")
    print(f"Location: {self.location}")

# %%
job_1 = job_info(job, salary, location)

# %%
job_1.display()
# Out:
# Job: Data Analyst
# Salary: 100000
# Location: india

# %%
job_2 = job_info('Data Scientist', 150000, 'USA')

# %%
job_2.display()
# Out:
# Job: Data Scientist
# Salary: 150000
# Location: USA
