# %% [markdown]
# <a href="https://colab.research.google.com/github/Devvrat12/Python-High-Level-Practice-Data-Engineer/blob/main/1_1_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hii, What's up Techie")
# Out:
# Hii, What's up Techie

# %%
def greet():
  return "Hii Techie"

# %%
greet()
# Out:
# 'Hii Techie'

# %%
def info(title, loc, sal):
  print(f"Job:       {title}\nLocation:  {loc}\nSalary:    {sal}")

# %%
role = "Data Analyst"
location = "Usa"
salary = 1000000

# %%
info(role, location, salary)
# Out:
# Job:       Data Analyst
# Location:  Usa
# Salary:    1000000
